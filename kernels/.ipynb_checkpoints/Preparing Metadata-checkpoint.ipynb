# %% [markdown]
# ## Preparing the Metadata
# The metadata extracted from the dicom images are extracted and then submited to the model to improve the results.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pydicom

import gc
import warnings

warnings.simplefilter(action = 'ignore')
file_path = "patients_meta.csv"

# %%
df_meta = pd.read_csv(file_path)

# %%
to_drop = df_meta.nunique()
to_drop = to_drop[(to_drop <= 1) | (to_drop == to_drop['patientId']) | 
                  (to_drop == to_drop['Unnamed: 0']
                  )].index
to_drop = to_drop.drop('patientId')
to_drop
# Out:
# Index(['Unnamed: 0', 'AccessionNumber', 'BitsAllocated', 'BitsStored',
#        'BodyPartExamined', 'Columns', 'ConversionType', 'HighBit',
#        'InstanceNumber', 'LossyImageCompression',
#        'LossyImageCompressionMethod', 'Modality', 'PatientBirthDate',
#        'PatientID', 'PatientName', 'PatientOrientation',
#        'PhotometricInterpretation', 'PixelRepresentation',
#        'ReferringPhysicianName', 'Rows', 'SOPClassUID', 'SOPInstanceUID',
#        'SamplesPerPixel', 'SeriesInstanceUID', 'SeriesNumber',
#        'SpecificCharacterSet', 'StudyDate', 'StudyID', 'StudyInstanceUID',
#        'StudyTime'],
#       dtype='object')

# %%
df_meta.drop(to_drop, axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#    PatientAge PatientSex SeriesDescription ViewPosition
# 0          51          F          view: PA           PA
# 1          48          F          view: PA           PA
# 2          19          M          view: AP           AP
# 3          28          M          view: PA           PA
# 4          32          F          view: AP           AP

# %%
df_meta.drop(df_meta[['x', 'y','height', 'width', 'SeriesDescription']], axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId  Target  PatientAge PatientSex  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6       0          51          F
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd       0          48          F
# 2  00322d4d-1c29-4943-afc9-b6754be640eb       0          19          M
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5       0          28          M
# 4  00436515-870c-4b36-a041-de91049b9ab4       1          32          F
#
#   ViewPosition
# 0           PA
# 1           PA
# 2           AP
# 3           PA
# 4           AP

# %% [markdown]
# ### Quantizing the numeric data

# %%
def quantize_age(value, year_interval=5):
    return ((value // year_interval) * year_interval) + 1

def quantize_age_10(value):
    return quantize_age(value, 10)

quantize_age(4), quantize_age(5), quantize_age(32), quantize_age(84), quantize_age(86), quantize_age(89)
# Out:
# (1, 6, 31, 81, 86, 86)

# %%
df_meta['PatientSex'] = df_meta['PatientSex'].map({'F': 0, 'M': 1})
df_meta['ViewPosition'] = df_meta['ViewPosition'].map({'PA': 0, 'AP': 1})
df_meta['age_5'] = df_meta['PatientAge'].map(quantize_age)
df_meta['age_10'] = df_meta['PatientAge'].map(quantize_age_10)
df_meta.head()
# Out:
#                               patientId  Target  PatientAge  PatientSex  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6       0          51           0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd       0          48           0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb       0          19           1
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5       0          28           1
# 4  00436515-870c-4b36-a041-de91049b9ab4       1          32           0
#
#    ViewPosition  age_5  age_10
# 0             0     51      51
# 1             0     46      41
# 2             1     16      11
# 3             0     26      21
# 4             1     31      31

# %%
df_meta['age_5'] /= 120 
df_meta['age_10'] /= 120

# %%
df_meta.drop('PatientAge', axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId  Target  PatientSex  ViewPosition  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6       0           0             0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd       0           0             0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb       0           1             1
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5       0           1             0
# 4  00436515-870c-4b36-a041-de91049b9ab4       1           0             1
#
#       age_5    age_10
# 0  0.425000  0.425000
# 1  0.383333  0.341667
# 2  0.133333  0.091667
# 3  0.216667  0.175000
# 4  0.258333  0.258333

# %%
df_meta.to_csv('extractfied_meta.csv')

# %%
df_meta.from_csv('extractfied_meta.csv')
df_meta.head()
# Out:
#                               patientId  Target  PatientSex  ViewPosition  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6       0           0             0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd       0           0             0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb       0           1             1
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5       0           1             0
# 4  00436515-870c-4b36-a041-de91049b9ab4       1           0             1
#
#       age_5    age_10
# 0  0.425000  0.425000
# 1  0.383333  0.341667
# 2  0.133333  0.091667
# 3  0.216667  0.175000
# 4  0.258333  0.258333

# %%
from PIL import Image
target_img  = '03e9a70f-3de8-4e13-b3f2-9dd6d75f496d'
output_dir='../rsna-pneumonia-retina/data/with_meta/'
image = Image.open(f'../rsna-pneumonia-retina/data/processed/train_png/{target_img}.png')

# %%
image.resize((224,224))
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7F9A94A7F5F8>

# %%
def get_img_meta(patient_id, img, df_meta):
    base_meta = df_meta[df_meta.patientId == patient_id].values[0][2:]
    meta_block = np.vstack([base_meta,base_meta,base_meta,base_meta])
    meta_channel = np.tile(meta_block, (56, 56))
    small_image = np.asarray(img.resize((224, 224)))
    fake_img=np.zeros((224, 224, 3), dtype=np.uint8)
    fake_img[:, :, 0] = np.asarray(small_image)
    fake_img[:, :, 1] = np.asarray(small_image)
    fake_img[:, :, 2] = meta_channel * 255
    
    return fake_img

# %%
fake_img = get_img_meta(target_img, image, df_meta)

# %%
plt.imshow(fake_img[:,:,0])

# %%
plt.imshow(fake_img[:,:,1])

# %%
plt.imshow(fake_img[:,:,2])

# %%
plt.imshow(255-fake_img )

# %%
plt.imshow(fake_img )

# %%
import cv2 

i = 0
sz = df_meta.patientId.unique().shape[0]
for patient_id in df_meta.patientId.unique(): 
    image = Image.open(f'../rsna-pneumonia-retina/data/processed/train_png/{patient_id}.png')    
    path = f'{output_dir}/{patient_id}.png'
    i+=1
    if (i % 100) == 0 or (i == sz):
        print(f'Progress {i}/{sz}')
        print(f'Saving {patient_id} as {path}')
        fake_img = get_img_meta(patient_id, image, df_meta)
        cv2.imwrite(path, fake_img)
        im2 = cv2.imread(path)
        plt.imshow(im2)
        plt.show()
# Out:
# Progress 100/26681
# Saving 03c149d1-e420-40bf-8d60-f98d0fff1d48 as /03c149d1-e420-40bf-8d60-f98d0fff1d48.png
# Progress 200/26681
# Saving 06415658-2590-4c38-a682-81acf9ef9a14 as /06415658-2590-4c38-a682-81acf9ef9a14.png
# Progress 300/26681
# Saving 0727efd2-c063-4409-b326-9532f6531a97 as /0727efd2-c063-4409-b326-9532f6531a97.png
# Progress 400/26681
# Saving 0803b0fa-c026-40d3-b9b6-43b843d17632 as /0803b0fa-c026-40d3-b9b6-43b843d17632.png
# Progress 500/26681
# Saving 08fda39f-ba68-45cc-9bbb-d416b19c6dc2 as /08fda39f-ba68-45cc-9bbb-d416b19c6dc2.png
# Progress 600/26681
# Saving 09d79f22-df14-4e5a-bc98-7a1d6bcd6965 as /09d79f22-df14-4e5a-bc98-7a1d6bcd6965.png
# Progress 700/26681
# Saving 0ae93f35-2954-41a2-a33b-6614f36dd1c3 as /0ae93f35-2954-41a2-a33b-6614f36dd1c3.png
# Progress 800/26681
# Saving 0bbb1ff7-dba6-4d5b-affe-b3ca0050d965 as /0bbb1ff7-dba6-4d5b-affe-b3ca0050d965.png
# Progress 900/26681
# Saving 0c89ca38-27ca-4cd0-88cb-18093fdcb04b as /0c89ca38-27ca-4cd0-88cb-18093fdcb04b.png
# Progress 1000/26681
# Saving 0fad7782-a936-4a72-8918-e3bc97cf690e as /0fad7782-a936-4a72-8918-e3bc97cf690e.png
# Progress 1100/26681
# Saving 1562c5c8-39cf-4fb2-8592-eafdeeeb5dd2 as /1562c5c8-39cf-4fb2-8592-eafdeeeb5dd2.png
# Progress 1200/26681
# Saving 1617a0bd-1dcf-45a5-8f0c-e0fcbadd48ce as /1617a0bd-1dcf-45a5-8f0c-e0fcbadd48ce.png
# Progress 1300/26681
# Saving 170632ff-5466-42a1-95f3-30ea4ef63e3b as /170632ff-5466-42a1-95f3-30ea4ef63e3b.png
# Progress 1400/26681
# Saving 17e5fca2-a7f4-44eb-9ecf-2fbfd4debf73 as /17e5fca2-a7f4-44eb-9ecf-2fbfd4debf73.png
# Progress 1500/26681
# Saving 18be2116-e8dd-4c42-8c56-8f2672e35bb7 as /18be2116-e8dd-4c42-8c56-8f2672e35bb7.png
# Progress 1600/26681
# Saving 1b3bc37d-dfa7-4dee-a7dc-18008b346586 as /1b3bc37d-dfa7-4dee-a7dc-18008b346586.png
# Progress 1700/26681
# Saving 2278d9f3-e7bf-4e36-a194-aaf5bdb20762 as /2278d9f3-e7bf-4e36-a194-aaf5bdb20762.png
# Progress 1800/26681
# Saving 281d879b-1f4a-4ef9-a88a-c311d31415ab as /281d879b-1f4a-4ef9-a88a-c311d31415ab.png
# Progress 1900/26681
# Saving 2e8d7684-3d6d-4516-b849-3666030db7b7 as /2e8d7684-3d6d-4516-b849-3666030db7b7.png
# Progress 2000/26681
# Saving 31a7fd05-b49d-4220-9268-33a61f4663a3 as /31a7fd05-b49d-4220-9268-33a61f4663a3.png
# Progress 2100/26681
# Saving 32827da4-939c-46de-85db-a2d75cb0dfad as /32827da4-939c-46de-85db-a2d75cb0dfad.png
# Progress 2200/26681
# Saving 336622cd-55bc-4404-beb1-8c75de224d0a as /336622cd-55bc-4404-beb1-8c75de224d0a.png
# Progress 2300/26681
# Saving 3454a6ae-2660-44c8-b15a-0f8a65ba0c6e as /3454a6ae-2660-44c8-b15a-0f8a65ba0c6e.png
# Progress 2400/26681
# Saving 3514e23d-3fbf-4695-9e81-ce5a83212984 as /3514e23d-3fbf-4695-9e81-ce5a83212984.png
# Progress 2500/26681
# Saving 35ef8c74-74d5-49ae-8b45-98d349344628 as /35ef8c74-74d5-49ae-8b45-98d349344628.png
# Progress 2600/26681
# Saving 36ef9113-5ea4-4812-a5ea-fdb0e3e028ba as /36ef9113-5ea4-4812-a5ea-fdb0e3e028ba.png
# Progress 2700/26681
# Saving 37b37037-486d-494d-948a-5d66d308dd45 as /37b37037-486d-494d-948a-5d66d308dd45.png
# Progress 2800/26681
# Saving 388c90bd-a30c-4ded-a5e9-50ef0a903467 as /388c90bd-a30c-4ded-a5e9-50ef0a903467.png
# Progress 2900/26681
# Saving 3934d9db-dc88-4a5f-8310-129c505d86c3 as /3934d9db-dc88-4a5f-8310-129c505d86c3.png
# Progress 3000/26681
# Saving 3a19bdf2-b88b-4414-97bd-b24d79cdd53d as /3a19bdf2-b88b-4414-97bd-b24d79cdd53d.png
# Progress 3100/26681
# Saving 3aebc0d6-6625-4e62-a895-53136bb34078 as /3aebc0d6-6625-4e62-a895-53136bb34078.png
# Progress 3200/26681
# Saving 3bc56686-1c63-4d08-b2ec-8e112db205a2 as /3bc56686-1c63-4d08-b2ec-8e112db205a2.png
# Progress 3300/26681
# Saving 3c92c85a-acb7-49dc-b732-1b6e203e6d7b as /3c92c85a-acb7-49dc-b732-1b6e203e6d7b.png
# Progress 3400/26681
# Saving 3d6c05e8-8db1-4d72-8cb5-8068b649161b as /3d6c05e8-8db1-4d72-8cb5-8068b649161b.png
# Progress 3500/26681
# Saving 3e5e1e9c-4b31-416a-a068-a4e2fc100f10 as /3e5e1e9c-4b31-416a-a068-a4e2fc100f10.png
# Progress 3600/26681
# Saving 3f382606-c1bd-4742-82f8-36feafa7e643 as /3f382606-c1bd-4742-82f8-36feafa7e643.png
# Progress 3700/26681
# Saving 402cf979-6bd9-48c2-9b9d-2f060881f55c as /402cf979-6bd9-48c2-9b9d-2f060881f55c.png
# Progress 3800/26681
# Saving 40f55d75-0e89-4392-a32c-84ff66530a4a as /40f55d75-0e89-4392-a32c-84ff66530a4a.png
# Progress 3900/26681
# Saving 41bd3bce-27fe-4ac5-b972-058614eab7ac as /41bd3bce-27fe-4ac5-b972-058614eab7ac.png
# Progress 4000/26681
# Saving 42ba9ff6-f422-444a-932b-b030624a9c2a as /42ba9ff6-f422-444a-932b-b030624a9c2a.png
# Progress 4100/26681
# Saving 43c93bad-8332-4df5-ba24-97638e7b422e as /43c93bad-8332-4df5-ba24-97638e7b422e.png
# Progress 4200/26681
# Saving 44a8fb24-5f75-4e9a-a187-70f3e608fd62 as /44a8fb24-5f75-4e9a-a187-70f3e608fd62.png
# Progress 4300/26681
# Saving 456df612-bc48-437d-a247-10a82d93e86e as /456df612-bc48-437d-a247-10a82d93e86e.png
# Progress 4400/26681
# Saving 464d7389-cbe4-46df-a2fe-b5c9bfca664e as /464d7389-cbe4-46df-a2fe-b5c9bfca664e.png
# Progress 4500/26681
# Saving 4717b1ad-61de-4dc6-a4cf-7a40951b59d3 as /4717b1ad-61de-4dc6-a4cf-7a40951b59d3.png
# Progress 4600/26681
# Saving 47f2c736-72d5-4897-b0c7-7119f0fd88c7 as /47f2c736-72d5-4897-b0c7-7119f0fd88c7.png
# Progress 4700/26681
# Saving 48e5400d-0821-4d48-b83e-92c3f24c6502 as /48e5400d-0821-4d48-b83e-92c3f24c6502.png
# Progress 4800/26681
# Saving 49c413cc-e806-4bc4-b744-1987261282c1 as /49c413cc-e806-4bc4-b744-1987261282c1.png
# Progress 4900/26681
# Saving 4aa7db1e-ea71-4b63-ae8a-877244ae1e06 as /4aa7db1e-ea71-4b63-ae8a-877244ae1e06.png
# Progress 5000/26681
# Saving 4b7d10d8-97b4-4d5b-9a74-01c7c8a13b10 as /4b7d10d8-97b4-4d5b-9a74-01c7c8a13b10.png
# Progress 5100/26681
# Saving 4c608577-dc40-44ab-9d91-c669c4c14bd0 as /4c608577-dc40-44ab-9d91-c669c4c14bd0.png
# Progress 5200/26681
# Saving 4d53c767-907b-4e70-870e-54cfd2aa86ec as /4d53c767-907b-4e70-870e-54cfd2aa86ec.png
# Progress 5300/26681
# Saving 4e2468e2-a8f0-4243-831b-6b227c913e64 as /4e2468e2-a8f0-4243-831b-6b227c913e64.png
# Progress 5400/26681
# Saving 4eff8749-55c8-4129-b2d4-fe35963037f2 as /4eff8749-55c8-4129-b2d4-fe35963037f2.png
# Progress 5500/26681
# Saving 4fd33b9b-f9fb-4b52-9858-1979e8d43777 as /4fd33b9b-f9fb-4b52-9858-1979e8d43777.png
# Progress 5600/26681
# Saving 5093633b-af1a-40b0-ab97-6aa4c586661f as /5093633b-af1a-40b0-ab97-6aa4c586661f.png
# Progress 5700/26681
# Saving 519eb46c-4578-43c5-82c7-c3dfe6b9b291 as /519eb46c-4578-43c5-82c7-c3dfe6b9b291.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-7997c3ff4ca1> in <module>
#       4 sz = df_meta.patientId.unique().shape[0]
#       5 for patient_id in df_meta.patientId.unique():
# ----> 6     image = Image.open(f'../rsna-pneumonia-retina/data/processed/train_png/{patient_id}.png')
#       7     path = f'{output_dir}/{patient_id}.png'
#       8     i+=1
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2607         return None
#    2608
# -> 2609     im = _open_core(fp, filename, prefix)
#    2610
#    2611     if im is None:
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in _open_core(fp, filename, prefix)
#    2597                 if not accept or accept(prefix):
#    2598                     fp.seek(0)
# -> 2599                     im = factory(fp, filename)
#    2600                     _decompression_bomb_check(im.size)
#    2601                     return im
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     100
#     101         try:
# --> 102             self._open()
#     103         except (IndexError,  # end of data
#     104                 TypeError,  # end of data (ord)
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in _open(self)
#     557             # get next chunk
#     558
# --> 559             cid, pos, length = self.png.read()
#     560
#     561             try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in read(self)
#     113             cid = s[4:]
#     114             pos = self.fp.tell()
# --> 115             length = i32(s)
#     116
#     117         if not is_cid(cid):
#
# /usr/local/lib/python3.6/dist-packages/PIL/_binary.py in i32be(c, o)
#      75
#      76 def i32be(c, o=0):
# ---> 77     return unpack_from(">I", c, o)[0]
#      78
#      79
#
# KeyboardInterrupt:
