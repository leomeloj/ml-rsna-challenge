# %% [markdown]
# ## Preparing the Metadata
# The metadata extracted from the dicom images are extracted and then submited to the model to improve the results.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pydicom

import gc
import warnings

warnings.simplefilter(action = 'ignore')
file_path = "test_patients_meta.csv"

# %%
df_meta = pd.read_csv(file_path)

# %%
to_drop = df_meta.nunique()
to_drop = to_drop[(to_drop <= 1) | (to_drop == to_drop['patientId']) | 
                  (to_drop == to_drop['Unnamed: 0']
                  )].index
to_drop = to_drop.drop('patientId')
to_drop
# Out:
# Index(['Unnamed: 0', 'AccessionNumber', 'BitsAllocated', 'BitsStored',
#        'BodyPartExamined', 'Columns', 'ConversionType', 'HighBit',
#        'InstanceNumber', 'LossyImageCompression',
#        'LossyImageCompressionMethod', 'Modality', 'PatientBirthDate',
#        'PatientID', 'PatientName', 'PatientOrientation',
#        'PhotometricInterpretation', 'PixelRepresentation',
#        'ReferringPhysicianName', 'Rows', 'SOPClassUID', 'SOPInstanceUID',
#        'SamplesPerPixel', 'SeriesInstanceUID', 'SeriesNumber',
#        'SpecificCharacterSet', 'StudyDate', 'StudyID', 'StudyInstanceUID',
#        'StudyTime'],
#       dtype='object')

# %%
df_meta.drop(to_drop, axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId  PatientAge PatientSex  \
# 0  11b01d48-9f9f-4c4f-b6e3-eb2df49e84b5          66          F
# 1  1e8359a0-6313-4908-9971-5682d02db185          29          M
# 2  0466a624-c075-4db1-9e03-f58d09bc27ff          30          F
# 3  26f31538-b674-4262-948b-74b0e9b4f872          48          F
# 4  13455fde-0e70-408a-a177-8acf2dfd1966          55          F
#
#   SeriesDescription ViewPosition
# 0          view: PA           PA
# 1          view: AP           AP
# 2          view: PA           PA
# 3          view: AP           AP
# 4          view: PA           PA

# %%
#df_meta.drop(df_meta[['x', 'y','height', 'width', 'SeriesDescription']], axis = 1, inplace = True)
df_meta.drop(df_meta[['SeriesDescription']], axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId  PatientAge PatientSex ViewPosition
# 0  11b01d48-9f9f-4c4f-b6e3-eb2df49e84b5          66          F           PA
# 1  1e8359a0-6313-4908-9971-5682d02db185          29          M           AP
# 2  0466a624-c075-4db1-9e03-f58d09bc27ff          30          F           PA
# 3  26f31538-b674-4262-948b-74b0e9b4f872          48          F           AP
# 4  13455fde-0e70-408a-a177-8acf2dfd1966          55          F           PA

# %% [markdown]
# ### Quantizing the numeric data

# %%
def quantize_age(value, year_interval=5):
    return ((value // year_interval) * year_interval) + 1

def quantize_age_10(value):
    return quantize_age(value, 10)

quantize_age(4), quantize_age(5), quantize_age(32), quantize_age(84), quantize_age(86), quantize_age(89)
# Out:
# (1, 6, 31, 81, 86, 86)

# %%
df_meta['PatientSex'] = df_meta['PatientSex'].map({'F': 0, 'M': 1})
df_meta['ViewPosition'] = df_meta['ViewPosition'].map({'PA': 0, 'AP': 1})
df_meta['age_5'] = df_meta['PatientAge'].map(quantize_age)
df_meta['age_10'] = df_meta['PatientAge'].map(quantize_age_10)
df_meta.head()
# Out:
#                               patientId  PatientAge  PatientSex  ViewPosition  \
# 0  11b01d48-9f9f-4c4f-b6e3-eb2df49e84b5          66           0             0
# 1  1e8359a0-6313-4908-9971-5682d02db185          29           1             1
# 2  0466a624-c075-4db1-9e03-f58d09bc27ff          30           0             0
# 3  26f31538-b674-4262-948b-74b0e9b4f872          48           0             1
# 4  13455fde-0e70-408a-a177-8acf2dfd1966          55           0             0
#
#    age_5  age_10
# 0     66      61
# 1     26      21
# 2     31      31
# 3     46      41
# 4     56      51

# %%
df_meta['age_5'] /= 120 
df_meta['age_10'] /= 120

# %%
df_meta.drop('PatientAge', axis = 1, inplace = True)
df_meta.head()
# Out:
#                               patientId  PatientSex  ViewPosition     age_5  \
# 0  11b01d48-9f9f-4c4f-b6e3-eb2df49e84b5           0             0  0.550000
# 1  1e8359a0-6313-4908-9971-5682d02db185           1             1  0.216667
# 2  0466a624-c075-4db1-9e03-f58d09bc27ff           0             0  0.258333
# 3  26f31538-b674-4262-948b-74b0e9b4f872           0             1  0.383333
# 4  13455fde-0e70-408a-a177-8acf2dfd1966           0             0  0.466667
#
#      age_10
# 0  0.508333
# 1  0.175000
# 2  0.258333
# 3  0.341667
# 4  0.425000

# %%
df_meta.to_csv('extractfied_meta.csv')

# %%
df_meta.from_csv('extractfied_meta.csv')
df_meta.head()
# Out:
#                               patientId  PatientSex  ViewPosition     age_5  \
# 0  11b01d48-9f9f-4c4f-b6e3-eb2df49e84b5           0             0  0.550000
# 1  1e8359a0-6313-4908-9971-5682d02db185           1             1  0.216667
# 2  0466a624-c075-4db1-9e03-f58d09bc27ff           0             0  0.258333
# 3  26f31538-b674-4262-948b-74b0e9b4f872           0             1  0.383333
# 4  13455fde-0e70-408a-a177-8acf2dfd1966           0             0  0.466667
#
#      age_10
# 0  0.508333
# 1  0.175000
# 2  0.258333
# 3  0.341667
# 4  0.425000

# %%
from PIL import Image
target_img  = '13455fde-0e70-408a-a177-8acf2dfd1966'
output_dir='..//test_data/with_meta/'
image = Image.open(f'..//test_data/stage_2_test_images/{target_img}.png')

# %%
image.resize((224,224))
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7FE7FC52E978>

# %%
def get_img_meta(patient_id, img, df_meta):
    #base_meta = df_meta[df_meta.patientId == patient_id].values[0][2:]
    base_meta = df_meta[df_meta.patientId == patient_id].values[0][1:]
    meta_block = np.vstack([base_meta,base_meta,base_meta,base_meta])
    meta_channel = np.tile(meta_block, (56, 56))
    small_image = np.asarray(img.resize((224, 224)))
    fake_img=np.zeros((224, 224, 3), dtype=np.uint8)
    fake_img[:, :, 0] = np.asarray(small_image)
    fake_img[:, :, 1] = np.asarray(small_image)
    fake_img[:, :, 2] = meta_channel * 255
    
    return fake_img

# %%
fake_img = get_img_meta(target_img, image, df_meta)

# %%
plt.imshow(fake_img[:,:,0])

# %%
plt.imshow(fake_img[:,:,1])

# %%
plt.imshow(fake_img[:,:,2])

# %%
plt.imshow(255-fake_img )

# %%
plt.imshow(fake_img )

# %%
import cv2 

i = 0
sz = df_meta.patientId.unique().shape[0]
for patient_id in df_meta.patientId.unique(): 
    image = Image.open(f'..//test_data/stage_2_test_images//{patient_id}.png')    
    path = f'{output_dir}/{patient_id}.png'
    i+=1
    fake_img = get_img_meta(patient_id, image, df_meta)
    cv2.imwrite(path, fake_img)    
    if (i % 100) == 0 or (i == sz):
        print(f'Progress {i}/{sz}')
        print(f'Saving {patient_id} as {path}')        
        im2 = cv2.imread(path)
        plt.imshow(im2)
        plt.show()
# Out:
# Progress 100/3000
# Saving 00ca48ec-39b3-4650-80ed-1fab342aba0e as ..//test_data/with_meta//00ca48ec-39b3-4650-80ed-1fab342aba0e.png
# Progress 200/3000
# Saving c13125e5-a27b-4110-bac3-7ed3ee2bfbb1 as ..//test_data/with_meta//c13125e5-a27b-4110-bac3-7ed3ee2bfbb1.png
# Progress 300/3000
# Saving 25b2b0ac-12f4-4bd5-9155-25d94a5f11ac as ..//test_data/with_meta//25b2b0ac-12f4-4bd5-9155-25d94a5f11ac.png
# Progress 400/3000
# Saving 23505b01-62da-4e56-bcdd-1adefde2cbb9 as ..//test_data/with_meta//23505b01-62da-4e56-bcdd-1adefde2cbb9.png
# Progress 500/3000
# Saving 237901d3-e135-4277-852a-86cba3a9a43e as ..//test_data/with_meta//237901d3-e135-4277-852a-86cba3a9a43e.png
# Progress 600/3000
# Saving 0106724a-2379-4897-8504-dfaa6db072de as ..//test_data/with_meta//0106724a-2379-4897-8504-dfaa6db072de.png
# Progress 700/3000
# Saving 21f7cfff-d8a5-4585-8dab-8cf4c13d991c as ..//test_data/with_meta//21f7cfff-d8a5-4585-8dab-8cf4c13d991c.png
# Progress 800/3000
# Saving 21b5ff6c-8c43-4473-8f45-5abf9cc15ff0 as ..//test_data/with_meta//21b5ff6c-8c43-4473-8f45-5abf9cc15ff0.png
# Progress 900/3000
# Saving bffaba0b-e40b-4a7c-acc0-694c015a905b as ..//test_data/with_meta//bffaba0b-e40b-4a7c-acc0-694c015a905b.png
# Progress 1000/3000
# Saving 13cd4766-358d-403a-9b39-d9909e79f78a as ..//test_data/with_meta//13cd4766-358d-403a-9b39-d9909e79f78a.png
# Progress 1100/3000
# Saving 047e8da3-51cd-4ce3-8fd7-b954844c6acc as ..//test_data/with_meta//047e8da3-51cd-4ce3-8fd7-b954844c6acc.png
# Progress 1200/3000
# Saving 23e99d2f-b0c5-4191-a5fe-8bcece4edd5b as ..//test_data/with_meta//23e99d2f-b0c5-4191-a5fe-8bcece4edd5b.png
# Progress 1300/3000
# Saving c187de8d-dff1-4f5f-b11e-74bd5bf8cfb8 as ..//test_data/with_meta//c187de8d-dff1-4f5f-b11e-74bd5bf8cfb8.png
# Progress 1400/3000
# Saving 01594bc6-16eb-4214-b2b2-4cf2154dbab9 as ..//test_data/with_meta//01594bc6-16eb-4214-b2b2-4cf2154dbab9.png
# Progress 1500/3000
# Saving 113b23a5-950e-49ee-ad17-c9dcdc2962b0 as ..//test_data/with_meta//113b23a5-950e-49ee-ad17-c9dcdc2962b0.png
# Progress 1600/3000
# Saving 29731a00-7f71-4bf2-b44b-1fc6e531dead as ..//test_data/with_meta//29731a00-7f71-4bf2-b44b-1fc6e531dead.png
# Progress 1700/3000
# Saving 2e27d646-1edc-4bb6-80e7-dc425c69f133 as ..//test_data/with_meta//2e27d646-1edc-4bb6-80e7-dc425c69f133.png
# Progress 1800/3000
# Saving 14d24e04-ff6e-458c-b26d-9c87f5789a60 as ..//test_data/with_meta//14d24e04-ff6e-458c-b26d-9c87f5789a60.png
# Progress 1900/3000
# Saving 30f042ff-13e4-4f89-be48-8d7ed8618ebd as ..//test_data/with_meta//30f042ff-13e4-4f89-be48-8d7ed8618ebd.png
# Progress 2000/3000
# Saving 02d8eb87-93ea-4e76-94fe-2fce14a93c6c as ..//test_data/with_meta//02d8eb87-93ea-4e76-94fe-2fce14a93c6c.png
# Progress 2100/3000
# Saving 231abfb6-8c40-43dd-923a-ee88d540ef50 as ..//test_data/with_meta//231abfb6-8c40-43dd-923a-ee88d540ef50.png
# Progress 2200/3000
# Saving 10090118-fe34-4225-bf51-62894ecb4994 as ..//test_data/with_meta//10090118-fe34-4225-bf51-62894ecb4994.png
# Progress 2300/3000
# Saving 1d796af7-6f80-4c3a-a3a9-099cc1fa5ddc as ..//test_data/with_meta//1d796af7-6f80-4c3a-a3a9-099cc1fa5ddc.png
# Progress 2400/3000
# Saving 265c655e-b97d-49b0-8b5c-83be37c0b80e as ..//test_data/with_meta//265c655e-b97d-49b0-8b5c-83be37c0b80e.png
# Progress 2500/3000
# Saving c07ea5c4-ce0a-4f94-bcfe-64c7399adb9c as ..//test_data/with_meta//c07ea5c4-ce0a-4f94-bcfe-64c7399adb9c.png
# Progress 2600/3000
# Saving 2aa6506f-a7a0-4057-bc65-e56a27370698 as ..//test_data/with_meta//2aa6506f-a7a0-4057-bc65-e56a27370698.png
# Progress 2700/3000
# Saving c1acfe9d-3e90-414c-809e-72c6dc153708 as ..//test_data/with_meta//c1acfe9d-3e90-414c-809e-72c6dc153708.png
# Progress 2800/3000
# Saving 1a61de89-b9f8-4771-ba89-d1de64d5a036 as ..//test_data/with_meta//1a61de89-b9f8-4771-ba89-d1de64d5a036.png
# Progress 2900/3000
# Saving 1ff240ca-a693-4a0e-926f-cc1e322e1569 as ..//test_data/with_meta//1ff240ca-a693-4a0e-926f-cc1e322e1569.png
# Progress 3000/3000
# Saving 2425f877-b1f8-44da-b8ea-adeb5155cc8b as ..//test_data/with_meta//2425f877-b1f8-44da-b8ea-adeb5155cc8b.png

# %%
plt.imshow(np.asarray(Image.open('..//test_data/with_meta//2425f877-b1f8-44da-b8ea-adeb5155cc8b.png').convert('RGB')))

# %%
df_meta.patientId.unique().shape[0]
# Out:
# 3000
