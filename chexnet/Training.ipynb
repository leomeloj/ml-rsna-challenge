# %% [markdown]
# # Training
# In this notebook we will tune the DenseNet121 that has already been trained in the dataset ChestXRay14. Many tests were perfgormed and are listed bellow:
#
# - (1) Fine-tunning last Fully Connected (FC) layer responsible for the classification.
# - (2) Fine-tunning some of the convolutional layers together with the classification layer
# - (3) Apply Transfer-Learning. That is, remove the last FC and emply classifiers like SVM, Random Forest, KNN, etc.

# %%
import visualize_prediction as V
import model as M
import pandas as pd

#suppress pytorch warnings about source code changes
import warnings
warnings.filterwarnings('ignore')
# Out:
# Available GPU count:1

# %% [markdown]
# ## Defining data path

# %%
PATH_TO_IMAGES = "dataset/"

# %% [markdown]
# ## (1) Fine-Tunning Classifier
# First we are tunning the last FC with our own data. For that purpose, the last FC that has been trained to distinguish between 14 classes is replaced with a binary one.

# %%
pred,aucs,model = M.fine_tunning_FC(PATH_TO_IMAGES, 0.001, 0.01)
# Out:
# - Loading Data
# - Transforming Images
# Epoch 1/100
# ----------
# train epoch 1:loss 0.6443 with data size 20537
# val epoch 1:loss 0.6305 with data size 5147
# saving
# Epoch 2/100
# ----------
# train epoch 2:loss 0.6397 with data size 20537
# val epoch 2:loss 0.6283 with data size 5147
# saving
# Epoch 3/100
# ----------
# train epoch 3:loss 0.6387 with data size 20537
# val epoch 3:loss 0.6307 with data size 5147
# decay loss from 0.001 to 0.0001 as not seeing improvement in val loss
# created new optimizer with LR 0.0001
# Epoch 4/100
# ----------
# train epoch 4:loss 0.6347 with data size 20537
# val epoch 4:loss 0.6268 with data size 5147
# saving
# Epoch 5/100
# ----------
# train epoch 5:loss 0.6347 with data size 20537
# val epoch 5:loss 0.6264 with data size 5147
# saving
# Epoch 6/100
# ----------
# train epoch 6:loss 0.6343 with data size 20537
# val epoch 6:loss 0.6262 with data size 5147
# saving
# Epoch 7/100
# ----------
# train epoch 7:loss 0.6348 with data size 20537
# val epoch 7:loss 0.6264 with data size 5147
# decay loss from 0.0001 to 1e-05 as not seeing improvement in val loss
# created new optimizer with LR 1e-05
# Epoch 8/100
# ----------
# train epoch 8:loss 0.6343 with data size 20537
# val epoch 8:loss 0.6265 with data size 5147
# decay loss from 1e-05 to 1.0000000000000002e-06 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000002e-06
# Epoch 9/100
# ----------
# train epoch 9:loss 0.6343 with data size 20537
# val epoch 9:loss 0.6263 with data size 5147
# decay loss from 1.0000000000000002e-06 to 1.0000000000000002e-07 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000002e-07
# no improvement in 3 epochs, break
# Training complete in 17m 55s
# 0
# 160
# 320
# 480
# 640
# 800
# 960
# 1120
# 1280
# 1440
# 1600
# 1760
# 1920
# 2080
# 2240
# 2400
# 2560
# 2720
# 2880
# 3040
# 3200
# 3360
# 3520
# 3680
# 3840
# 4000
# 4160
# 4320
# 4480
# 4640
# 4800
# 4960
# 5120

# %%
print(pred)
print(aucs)

# %% [markdown]
# ## (2) Fine-Tunning Conv. Layers

# %%
pred,aucs,model = M.fine_tunning_conv(PATH_TO_IMAGES, 0.001, 0.01, 10)
# Out:
# - Loading Data
# - Transforming Images
# Epoch 1/100
# ----------
# train epoch 1:loss 0.6408 with data size 20537
# val epoch 1:loss 0.6263 with data size 5147
# saving
# Epoch 2/100
# ----------
# train epoch 2:loss 0.6362 with data size 20537
# val epoch 2:loss 0.6239 with data size 5147
# saving
# Epoch 3/100
# ----------
# train epoch 3:loss 0.6341 with data size 20537
# val epoch 3:loss 0.6238 with data size 5147
# saving
# Epoch 4/100
# ----------
# train epoch 4:loss 0.6321 with data size 20537
# val epoch 4:loss 0.6240 with data size 5147
# decay loss from 0.001 to 0.0001 as not seeing improvement in val loss
# created new optimizer with LR 0.0001
# Epoch 5/100
# ----------
# train epoch 5:loss 0.6296 with data size 20537
# val epoch 5:loss 0.6230 with data size 5147
# saving
# Epoch 6/100
# ----------
# train epoch 6:loss 0.6296 with data size 20537
# val epoch 6:loss 0.6228 with data size 5147
# saving
# Epoch 7/100
# ----------
# train epoch 7:loss 0.6285 with data size 20537
# val epoch 7:loss 0.6228 with data size 5147
# saving
# Epoch 8/100
# ----------
# train epoch 8:loss 0.6284 with data size 20537
# val epoch 8:loss 0.6241 with data size 5147
# decay loss from 0.0001 to 1e-05 as not seeing improvement in val loss
# created new optimizer with LR 1e-05
# Epoch 9/100
# ----------
# train epoch 9:loss 0.6282 with data size 20537
# val epoch 9:loss 0.6229 with data size 5147
# decay loss from 1e-05 to 1.0000000000000002e-06 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000002e-06
# Epoch 10/100
# ----------
# train epoch 10:loss 0.6285 with data size 20537
# val epoch 10:loss 0.6228 with data size 5147
# saving
# Epoch 11/100
# ----------
# train epoch 11:loss 0.6277 with data size 20537
# val epoch 11:loss 0.6230 with data size 5147
# decay loss from 1.0000000000000002e-06 to 1.0000000000000002e-07 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000002e-07
# Epoch 12/100
# ----------
# train epoch 12:loss 0.6273 with data size 20537
# val epoch 12:loss 0.6229 with data size 5147
# decay loss from 1.0000000000000002e-07 to 1.0000000000000002e-08 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000002e-08
# Epoch 13/100
# ----------
# train epoch 13:loss 0.6279 with data size 20537
# val epoch 13:loss 0.6231 with data size 5147
# decay loss from 1.0000000000000002e-08 to 1.0000000000000003e-09 as not seeing improvement in val loss
# created new optimizer with LR 1.0000000000000003e-09
# no improvement in 3 epochs, break
# Training complete in 29m 12s
# 0
# 160
# 320
# 480
# 640
# 800
# 960
# 1120
# 1280
# 1440
# 1600
# 1760
# 1920
# 2080
# 2240
# 2400
# 2560
# 2720
# 2880
# 3040
# 3200
# 3360
# 3520
# 3680
# 3840
# 4000
# 4160
# 4320
# 4480
# 4640
# 4800
# 4960
# 5120

# %%
print(pred)
print(aucs)
# Out:
#                                      patientId  prob_Pneumonia  \
# 0     00313ee0-9eaa-42f4-b0ab-c148ed3241cd.png        0.531698
efdd549-9fbd-4e90-a7e4-4a0d2d4466d6.png        0.827422
# 5124  ff00eb58-e9c8-4c4b-8837-88355b3b7d2b.png        0.748340
# 5125  ff0200e1-3bac-42d1-880b-17d6a3366d2c.png        0.907411
# 5126  ff332704-48e0-445b-9188-b2a696d1f0d7.png        0.493287
# 5127  ff33da14-0bd6-4fe4-9675-ef704bc33b84.png        0.918590
# 5128  ff371a27-7df6-4aaf-a5eb-5e64acc4a054.png        0.514545
# 5129  ff3c2e94-b672-4bd2-8073-e9a4b6d9294d.png        0.519476
# 5130  ff42dbdc-285e-457d-aa3d-725638fa083b.png        0.543311
# 5131  ff551276-6116-4e99-aeb8-e59eb8f6ce0a.png        0.501007
# 5132  ff659b3e-123c-4501-ab4b-be41216160ac.png        0.510410
# 5133  ff7bd314-e7ee-4f20-9734-bd4350f091d1.png        0.626449
# 5134  ff955beb-6f41-4292-adf7-f224054c882f.png        0.505592
# 5135  ff9c582d-938e-426b-8430-14183c3c1ded.png        0.508673
# 5136  ff9d37d1-3660-4187-8f57-d31f9c91a3fd.png        0.764056
# 5137  ffabea71-fba0-49ff-a038-2b1dac9971b7.png        0.635698
# 5138  ffad4160-d78e-4bcc-ab1f-47e20e613bd6.png        0.544970
# 5139  ffae40ab-fcfe-4311-a74a-89f605dba48b.png        0.607247
# 5140  ffba6230-71cf-4287-a0d1-887f5d16e95d.png        0.487428
# 5141  ffc3fc59-f046-48b8-b7ad-3a9e07362d0c.png        0.517860
# 5142  ffc9e552-ca53-43a8-a156-b0f97f0d40f3.png        0.544071
# 5143  ffd670a5-b6dc-4f54-928a-69b7a04662eb.png        0.628294
# 5144  ffdc771e-1f1a-47f7-b732-3e06e48c24e8.png        0.573272
# 5145  fff0b503-72a5-446a-843d-f3d152e39053.png        0.849320
# 5146  fffb2395-8edd-4954-8a89-ffe2fd329be3.png        0.969122
#
#       prob_not Pneumonia
# 0               0.468302
# 1               0.236274
# 2               0.475234
# 3               0.245508
# 4               0.375377
# 5               0.501317
# 6               0.289198
# 7               0.392299
# 8               0.518748
# 9               0.464726
# 10              0.463978
# 11              0.500585
# 12              0.504367
# 13              0.152754
# 14              0.404446
# 15              0.236597
# 16              0.383801
# 17              0.524962
# 18              0.041267
# 19              0.510613
# 20              0.371116
# 21              0.470154
# 22              0.413711
# 23              0.140641
# 24              0.233187
# 25              0.347576
# 26              0.500882
# 27              0.454743
# 28              0.455654
# 29              0.466062
# ...                  ...
# 5117            0.220303
# 5118            0.486071
# 5119            0.462680
# 5120            0.183630
# 5121            0.393973
# 5122            0.398141
# 5123            0.172578
# 5124            0.251660
# 5125            0.092589
# 5126            0.506713
# 5127            0.081410
# 5128            0.485455
# 5129            0.480524
# 5130            0.456689
# 5131            0.498993
# 5132            0.489590
# 5133            0.373551
# 5134            0.494408
# 5135            0.491327
# 5136            0.235944
# 5137            0.364302
# 5138            0.455030
# 5139            0.392753
# 5140            0.512572
# 5141            0.482140
# 5142            0.455929
# 5143            0.371706
# 5144            0.426728
# 5145            0.150680
# 5146            0.030878
#
# [5147 rows x 3 columns]
#        label       auc
# 0  Pneumonia  0.889434
